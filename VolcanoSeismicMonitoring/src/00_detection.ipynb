# %% [markdown]
# # Event Detection (& Association)
# The first stage of the monitoring process is to detect anomalous events - short, transient signals of a few seconds to 1-2 minutes. The classic approach (since late 1970s?) has been to use a Short-Term Average (STA) to Long-Term Average (LTA) ratio-based Detector.
#
# ## Steps:
# - Run an <b>STA/LTA Detector</b> on each channel of continuous waveform data (to each ObsPy Trace object wthin a Stream object).This yields a set of Trigger (or Detection) ON and OFF times.
# - Run an <b>Associator</b> on the full set of Triggers. If multiple channels have Trigger ON status at the same time, record as an Event in a Catalog.
#
# In ObsPy, both steps can be done using `coincidence_trigger` from the `obspy.signal.trigger` package.
#
# ## Examples:
# 1. Run an STA/LTA Detector on a single channel of data, on just 1 hour of data.
# 2. Run an STA/LTA Detector and Associator on multiple channels of data (a Stream object), on just 1 hour of data.
# 3. Run an STA/LTA Detection and Associator on multiple channels of data (a Stream object), for multiple days of data.
#
# The continuous waveform data will come from a "SeisComP Data Structure" (https://docs.obspy.org/packages/autogen/obspy.clients.filesystem.sds.html) or "SDS" archive. We will explore this first. We can create a client connection to as SDS archive using the Client class from the `obspy.clients.filesystem.sds` package.

# %%
# Import general packages
import os
import sys
from pathlib import Path
import obspy

# Import local packages
sys.path.append('..')
import vsmTools

# Define where SDS archive and EVENTS data are stored
SDS_DIR = os.path.join('..', 'data','continuous','SDS')
EVENTS_DIR = os.path.join('..', 'data','events')
CATALOG_DIR = os.path.join('..', 'data','catalogs')

# Create a connection to an SDS archive
from obspy.clients.filesystem.sds import Client
sdsclient = Client(SDS_DIR)

# Show a tree listing of SDS_DIR
print('Tree listing of SDS_DIR directory')
for line in vsmTools.tree(Path(SDS_DIR)):
    print(line)

# Set start time as "YYYYJJJT" where JJJ = (Julian calendar) day of year
stime = obspy.UTCDateTime("2003196T")
print(stime)
# Out:
# Tree listing of SDS_DIR directory
# ├── 2001
# │   └── MV
# │       ├── MBRY
# │       │   ├── BHE.D
# │       │   │   ├── MV.MBRY..BHE.D.2001.208
# │       │   │   ├── MV.MBRY..BHE.D.2001.209
# │       │   │   ├── MV.MBRY..BHE.D.2001.211
# │       │   │   ├── MV.MBRY..BHE.D.2001.212
# │       │   │   ├── MV.MBRY..BHE.D.2001.207
# │       │   │   ├── MV.MBRY..BHE.D.2001.214
# │       │   │   ├── MV.MBRY..BHE.D.2001.210
# │       │   │   └── MV.MBRY..BHE.D.2001.213
# │       │   ├── BHN.D
# │       │   │   ├── MV.MBRY..BHN.D.2001.212
# │       │   │   ├── MV.MBRY..BHN.D.2001.211
# │       │   │   ├── MV.MBRY..BHN.D.2001.207
# │       │   │   ├── MV.MBRY..BHN.D.2001.214
# │       │   │   ├── MV.MBRY..BHN.D.2001.208
# │       │   │   ├── MV.MBRY..BHN.D.2001.213
# │       │   │   ├── MV.MBRY..BHN.D.2001.209
# │       │   │   └── MV.MBRY..BHN.D.2001.210
# │       │   └── BHZ.D
# │       │       ├── MV.MBRY..BHZ.D.2001.211
# │       │       ├── MV.MBRY..BHZ.D.2001.210
# │       │       ├── MV.MBRY..BHZ.D.2001.208
# │       │       ├── MV.MBRY..BHZ.D.2001.213
# │       │       ├── MV.MBRY..BHZ.D.2001.207
# │       │       ├── MV.MBRY..BHZ.D.2001.209
# │       │       ├── MV.MBRY..BHZ.D.2001.212
# │       │       └── MV.MBRY..BHZ.D.2001.214
# │       ├── MBWH
# │       │   └── SHZ.D
# │       │       ├── MV.MBWH..SHZ.D.2001.209
# │       │       ├── MV.MBWH..SHZ.D.2001.211
# │       │       ├── MV.MBWH..SHZ.D.2001.207
# │       │       ├── MV.MBWH..SHZ.D.2001.210
# │       │       ├── MV.MBWH..SHZ.D.2001.212
# │       │       ├── MV.MBWH..SHZ.D.2001.213
# │       │       ├── MV.MBWH..SHZ.D.2001.208
# │       │       └── MV.MBWH..SHZ.D.2001.214
# │       ├── MBGH
# │       │   ├── BHE.D
# │       │   │   ├── MV.MBGH..BHE.D.2001.210
# │       │   │   ├── MV.MBGH..BHE.D.2001.214
# │       │   │   ├── MV.MBGH..BHE.D.2001.209
# │       │   │   ├── MV.MBGH..BHE.D.2001.213
# │       │   │   ├── MV.MBGH..BHE.D.2001.211
# │       │   │   ├── MV.MBGH..BHE.D.2001.208
# │       │   │   ├── MV.MBGH..BHE.D.2001.207
# │       │   │   └── MV.MBGH..BHE.D.2001.212
# │       │   ├── BHN.D
# │       │   │   ├── MV.MBGH..BHN.D.2001.209
# │       │   │   ├── MV.MBGH..BHN.D.2001.214
# │       │   │   ├── MV.MBGH..BHN.D.2001.210
# │       │   │   ├── MV.MBGH..BHN.D.2001.207
# │       │   │   ├── MV.MBGH..BHN.D.2001.213
# │       │   │   ├── MV.MBGH..BHN.D.2001.208
# │       │   │   ├── MV.MBGH..BHN.D.2001.212
# │       │   │   └── MV.MBGH..BHN.D.2001.211
# │       │   └── BHZ.D
# │       │       ├── MV.MBGH..BHZ.D.2001.211
# │       │       ├── MV.MBGH..BHZ.D.2001.214
# │       │       ├── MV.MBGH..BHZ.D.2001.212
# │       │       ├── MV.MBGH..BHZ.D.2001.213
# │       │       ├── MV.MBGH..BHZ.D.2001.208
# │       │       ├── MV.MBGH..BHZ.D.2001.209
# │       │       ├── MV.MBGH..BHZ.D.2001.207
# │       │       └── MV.MBGH..BHZ.D.2001.210
# │       ├── MBBY
# │       │   ├── BHE.D
# │       │   │   ├── MV.MBBY..BHE.D.2001.214
# │       │   │   ├── MV.MBBY..BHE.D.2001.212
# │       │   │   ├── MV.MBBY..BHE.D.2001.209
# │       │   │   ├── MV.MBBY..BHE.D.2001.208
# │       │   │   ├── MV.MBBY..BHE.D.2001.213
# │       │   │   ├── MV.MBBY..BHE.D.2001.207
# │       │   │   ├── MV.MBBY..BHE.D.2001.210
# │       │   │   └── MV.MBBY..BHE.D.2001.211
# │       │   ├── BHN.D
# │       │   │   ├── MV.MBBY..BHN.D.2001.208
# │       │   │   ├── MV.MBBY..BHN.D.2001.210
# │       │   │   ├── MV.MBBY..BHN.D.2001.214
# │       │   │   ├── MV.MBBY..BHN.D.2001.212
# │       │   │   ├── MV.MBBY..BHN.D.2001.213
# │       │   │   ├── MV.MBBY..BHN.D.2001.209
# │       │   │   ├── MV.MBBY..BHN.D.2001.211
# │       │   │   └── MV.MBBY..BHN.D.2001.207
# │       │   └── BHZ.D
# │       │       ├── MV.MBBY..BHZ.D.2001.210
# │       │       ├── MV.MBBY..BHZ.D.2001.209
# │       │       ├── MV.MBBY..BHZ.D.2001.212
# │       │       ├── MV.MBBY..BHZ.D.2001.211
# │       │       ├── MV.MBBY..BHZ.D.2001.207
# │       │       ├── MV.MBBY..BHZ.D.2001.213
# │       │       ├── MV.MBBY..BHZ.D.2001.214
# │       │       └── MV.MBBY..BHZ.D.2001.208
# │       ├── MBLG
# │       │   └── SHZ.D
# │       │       ├── MV.MBLG..SHZ.D.2001.209
# │       │       ├── MV.MBLG..SHZ.D.2001.214
# │       │       ├── MV.MBLG..SHZ.D.2001.208
# │       │       ├── MV.MBLG..SHZ.D.2001.212
# │       │       ├── MV.MBLG..SHZ.D.2001.210
# │       │       ├── MV.MBLG..SHZ.D.2001.207
# │       │       ├── MV.MBLG..SHZ.D.2001.211
# │       │       └── MV.MBLG..SHZ.D.2001.213
# │       ├── MBSS
# │       │   └── SHZ.D
# │       │       ├── MV.MBSS..SHZ.D.2001.213
# │       │       ├── MV.MBSS..SHZ.D.2001.212
# │       │       ├── MV.MBSS..SHZ.D.2001.207
# │       │       ├── MV.MBSS..SHZ.D.2001.210
# │       │       ├── MV.MBSS..SHZ.D.2001.209
# │       │       ├── MV.MBSS..SHZ.D.2001.211
# │       │       ├── MV.MBSS..SHZ.D.2001.214
# │       │       └── MV.MBSS..SHZ.D.2001.208
# │       ├── MBGB
# │       │   ├── BHE.D
# │       │   │   ├── MV.MBGB..BHE.D.2001.208
# │       │   │   ├── MV.MBGB..BHE.D.2001.213
# │       │   │   ├── MV.MBGB..BHE.D.2001.207
# │       │   │   ├── MV.MBGB..BHE.D.2001.209
# │       │   │   ├── MV.MBGB..BHE.D.2001.212
# │       │   │   ├── MV.MBGB..BHE.D.2001.210
# │       │   │   ├── MV.MBGB..BHE.D.2001.211
# │       │   │   └── MV.MBGB..BHE.D.2001.214
# │       │   ├── BHN.D
# │       │   │   ├── MV.MBGB..BHN.D.2001.212
# │       │   │   ├── MV.MBGB..BHN.D.2001.214
# │       │   │   ├── MV.MBGB..BHN.D.2001.209
# │       │   │   ├── MV.MBGB..BHN.D.2001.207
# │       │   │   ├── MV.MBGB..BHN.D.2001.213
# │       │   │   ├── MV.MBGB..BHN.D.2001.211
# │       │   │   ├── MV.MBGB..BHN.D.2001.208
# │       │   │   └── MV.MBGB..BHN.D.2001.210
# │       │   └── BHZ.D
# │       │       ├── MV.MBGB..BHZ.D.2001.210
# │       │       ├── MV.MBGB..BHZ.D.2001.208
# │       │       ├── MV.MBGB..BHZ.D.2001.213
# │       │       ├── MV.MBGB..BHZ.D.2001.214
# │       │       ├── MV.MBGB..BHZ.D.2001.209
# │       │       ├── MV.MBGB..BHZ.D.2001.207
# │       │       ├── MV.MBGB..BHZ.D.2001.211
# │       │       └── MV.MBGB..BHZ.D.2001.212
# │       └── MBMH
# │           ├── SHZ.D
# │           │   ├── MV.MBMH..SHZ.D.2001.212
# │           │   ├── MV.MBMH..SHZ.D.2001.211
# │           │   ├── MV.MBMH..SHZ.D.2001.207
# │           │   ├── MV.MBMH..SHZ.D.2001.210
# │           │   ├── MV.MBMH..SHZ.D.2001.213
# │           │   ├── MV.MBMH..SHZ.D.2001.209
# │           │   ├── MV.MBMH..SHZ.D.2001.214
# │           │   └── MV.MBMH..SHZ.D.2001.208
# │           ├── SHE.D
# │           │   ├── MV.MBMH..SHE.D.2001.208
# │           │   ├── MV.MBMH..SHE.D.2001.207
# │           │   ├── MV.MBMH..SHE.D.2001.210
# │           │   ├── MV.MBMH..SHE.D.2001.209
# │           │   ├── MV.MBMH..SHE.D.2001.213
# │           │   ├── MV.MBMH..SHE.D.2001.214
# │           │   ├── MV.MBMH..SHE.D.2001.211
# │           │   └── MV.MBMH..SHE.D.2001.212
# │           └── SHN.D
# │               ├── MV.MBMH..SHN.D.2001.207
# │               ├── MV.MBMH..SHN.D.2001.210
# │               ├── MV.MBMH..SHN.D.2001.208
# │               ├── MV.MBMH..SHN.D.2001.212
# │               ├── MV.MBMH..SHN.D.2001.211
# │               ├── MV.MBMH..SHN.D.2001.214
# │               ├── MV.MBMH..SHN.D.2001.209
# │               └── MV.MBMH..SHN.D.2001.213
# ├── .DS_Store
# ├── 2009
# │   └── AV
# │       └── REF
# │           └── EHZ.D
# │               └── AV.REF..EHZ.D.2009.081
# ├── ._2009
# └── 2003
#     ├── .DS_Store
#     └── MV
#         ├── MBRY
#         │   ├── BHE.D
#         │   │   ├── MV.MBRY..BHE.D.2003.189
#         │   │   ├── MV.MBRY..BHE.D.2003.187
#         │   │   ├── MV.MBRY..BHE.D.2003.191
#         │   │   ├── MV.MBRY..BHE.D.2003.192
#         │   │   ├── MV.MBRY..BHE.D.2003.188
#         │   │   └── MV.MBRY..BHE.D.2003.190
#         │   ├── BHN.D
#         │   │   ├── MV.MBRY..BHN.D.2003.191
#         │   │   ├── MV.MBRY..BHN.D.2003.189
#         │   │   ├── MV.MBRY..BHN.D.2003.188
#         │   │   ├── MV.MBRY..BHN.D.2003.190
#         │   │   ├── MV.MBRY..BHN.D.2003.192
#         │   │   └── MV.MBRY..BHN.D.2003.187
#         │   └── BHZ.D
#         │       ├── MV.MBRY..BHZ.D.2003.197
#         │       ├── MV.MBRY..BHZ.D.2003.196
#         │       ├── MV.MBRY..BHZ.D.2003.195
#         │       ├── MV.MBRY..BHZ.D.2003.192
#         │       ├── MV.MBRY..BHZ.D.2003.193
#         │       ├── MV.MBRY..BHZ.D.2003.187
#         │       ├── MV.MBRY..BHZ.D.2003.190
#         │       ├── MV.MBRY..BHZ.D.2003.189
#         │       ├── MV.MBRY..BHZ.D.2003.188
#         │       ├── MV.MBRY..BHZ.D.2003.191
#         │       └── MV.MBRY..BHZ.D.2003.194
#         ├── .DS_Store
#         ├── MBWH
#         │   └── SHZ.D
#         │       ├── MV.MBWH..SHZ.D.2003.194
#         │       ├── MV.MBWH..SHZ.D.2003.193
#         │       ├── MV.MBWH..SHZ.D.2003.192
#         │       ├── MV.MBWH..SHZ.D.2003.191
#         │       ├── MV.MBWH..SHZ.D.2003.197
#         │       ├── MV.MBWH..SHZ.D.2003.196
#         │       ├── MV.MBWH..SHZ.D.2003.187
#         │       ├── MV.MBWH..SHZ.D.2003.195
#         │       ├── MV.MBWH..SHZ.D.2003.188
#         │       ├── MV.MBWH..SHZ.D.2003.190
#         │       └── MV.MBWH..SHZ.D.2003.189
#         ├── MBGH
#         │   ├── BHE.D
#         │   │   ├── MV.MBGH..BHE.D.2003.190
#         │   │   ├── MV.MBGH..BHE.D.2003.187
#         │   │   ├── MV.MBGH..BHE.D.2003.188
#         │   │   ├── MV.MBGH..BHE.D.2003.189
#         │   │   ├── MV.MBGH..BHE.D.2003.191
#         │   │   └── MV.MBGH..BHE.D.2003.192
#         │   ├── BHN.D
#         │   │   ├── MV.MBGH..BHN.D.2003.187
#         │   │   ├── MV.MBGH..BHN.D.2003.191
#         │   │   ├── MV.MBGH..BHN.D.2003.192
#         │   │   ├── MV.MBGH..BHN.D.2003.189
#         │   │   ├── MV.MBGH..BHN.D.2003.188
#         │   │   └── MV.MBGH..BHN.D.2003.190
#         │   └── BHZ.D
#         │       ├── MV.MBGH..BHZ.D.2003.197
#         │       ├── MV.MBGH..BHZ.D.2003.194
#         │       ├── MV.MBGH..BHZ.D.2003.189
#         │       ├── MV.MBGH..BHZ.D.2003.193
#         │       ├── MV.MBGH..BHZ.D.2003.195
#         │       ├── MV.MBGH..BHZ.D.2003.196
#         │       ├── MV.MBGH..BHZ.D.2003.192
#         │       ├── MV.MBGH..BHZ.D.2003.190
#         │       ├── MV.MBGH..BHZ.D.2003.188
#         │       ├── MV.MBGH..BHZ.D.2003.191
#         │       └── MV.MBGH..BHZ.D.2003.187
#         ├── MBLG
#         │   ├── SHZ.D
#         │   │   ├── MV.MBLG..SHZ.D.2003.187
#         │   │   ├── MV.MBLG..SHZ.D.2003.192
#         │   │   ├── MV.MBLG..SHZ.D.2003.195
#         │   │   ├── MV.MBLG..SHZ.D.2003.191
#         │   │   ├── MV.MBLG..SHZ.D.2003.189
#         │   │   ├── MV.MBLG..SHZ.D.2003.190
#         │   │   ├── MV.MBLG..SHZ.D.2003.197
#         │   │   ├── MV.MBLG..SHZ.D.2003.193
#         │   │   ├── MV.MBLG..SHZ.D.2003.196
#         │   │   ├── MV.MBLG..SHZ.D.2003.194
#         │   │   └── MV.MBLG..SHZ.D.2003.188
#         │   └── APS.D
#         │       ├── MV.MBLG..APS.D.2003.192
#         │       ├── MV.MBLG..APS.D.2003.189
#         │       ├── MV.MBLG..APS.D.2003.190
#         │       ├── MV.MBLG..APS.D.2003.191
#         │       ├── MV.MBLG..APS.D.2003.188
#         │       └── MV.MBLG..APS.D.2003.187
#         ├── MBLY
#         │   ├── BHE.D
#         │   │   ├── MV.MBLY..BHE.D.2003.188
#         │   │   ├── MV.MBLY..BHE.D.2003.192
#         │   │   ├── MV.MBLY..BHE.D.2003.189
#         │   │   ├── MV.MBLY..BHE.D.2003.187
#         │   │   ├── MV.MBLY..BHE.D.2003.190
#         │   │   └── MV.MBLY..BHE.D.2003.191
#         │   ├── BHN.D
#         │   │   ├── MV.MBLY..BHN.D.2003.192
#         │   │   ├── MV.MBLY..BHN.D.2003.190
#         │   │   ├── MV.MBLY..BHN.D.2003.188
#         │   │   ├── MV.MBLY..BHN.D.2003.191
#         │   │   ├── MV.MBLY..BHN.D.2003.187
#         │   │   └── MV.MBLY..BHN.D.2003.189
#         │   └── BHZ.D
#         │       ├── MV.MBLY..BHZ.D.2003.192
#         │       ├── MV.MBLY..BHZ.D.2003.187
#         │       ├── MV.MBLY..BHZ.D.2003.195
#         │       ├── MV.MBLY..BHZ.D.2003.193
#         │       ├── MV.MBLY..BHZ.D.2003.196
#         │       ├── MV.MBLY..BHZ.D.2003.191
#         │       ├── MV.MBLY..BHZ.D.2003.190
#         │       ├── MV.MBLY..BHZ.D.2003.188
#         │       ├── MV.MBLY..BHZ.D.2003.197
#         │       ├── MV.MBLY..BHZ.D.2003.194
#         │       └── MV.MBLY..BHZ.D.2003.189
#         ├── MBSS
#         │   └── SHZ.D
#         │       ├── MV.MBSS..SHZ.D.2003.192
#         │       ├── MV.MBSS..SHZ.D.2003.195
#         │       ├── MV.MBSS..SHZ.D.2003.197
#         │       ├── MV.MBSS..SHZ.D.2003.190
#         │       ├── MV.MBSS..SHZ.D.2003.187
#         │       ├── MV.MBSS..SHZ.D.2003.194
#         │       ├── MV.MBSS..SHZ.D.2003.189
#         │       ├── MV.MBSS..SHZ.D.2003.188
#         │       ├── MV.MBSS..SHZ.D.2003.191
#         │       ├── MV.MBSS..SHZ.D.2003.193
#         │       └── MV.MBSS..SHZ.D.2003.196
#         ├── MBGB
#         │   ├── .DS_Store
#         │   ├── BHE.D
#         │   │   ├── MV.MBGB..BHE.D.2003.189
#         │   │   ├── MV.MBGB..BHE.D.2003.190
#         │   │   ├── MV.MBGB..BHE.D.2003.192
#         │   │   ├── MV.MBGB..BHE.D.2003.191
#         │   │   ├── MV.MBGB..BHE.D.2003.188
#         │   │   └── MV.MBGB..BHE.D.2003.187
#         │   ├── BHN.D
#         │   │   ├── MV.MBGB..BHN.D.2003.190
#         │   │   ├── MV.MBGB..BHN.D.2003.188
#         │   │   ├── MV.MBGB..BHN.D.2003.192
#         │   │   ├── MV.MBGB..BHN.D.2003.191
#         │   │   ├── MV.MBGB..BHN.D.2003.187
#         │   │   └── MV.MBGB..BHN.D.2003.189
#         │   └── BHZ.D
#         │       ├── MV.MBGB..BHZ.D.2003.194
#         │       ├── MV.MBGB..BHZ.D.2003.188
#         │       ├── MV.MBGB..BHZ.D.2003.187
#         │       ├── MV.MBGB..BHZ.D.2003.189
#         │       ├── MV.MBGB..BHZ.D.2003.193
#         │       ├── MV.MBGB..BHZ.D.2003.192
#         │       ├── MV.MBGB..BHZ.D.2003.191
#         │       ├── MV.MBGB..BHZ.D.2003.190
#         │       ├── MV.MBGB..BHZ.D.2003.195
#         │       ├── MV.MBGB..BHZ.D.2003.197
#         │       └── MV.MBGB..BHZ.D.2003.196
#         └── MBRV
#             └── SHZ.D
#                 ├── MV.MBRV..SHZ.D.2003.192
#                 ├── MV.MBRV..SHZ.D.2003.189
#                 ├── MV.MBRV..SHZ.D.2003.191
#                 ├── MV.MBRV..SHZ.D.2003.196
#                 ├── MV.MBRV..SHZ.D.2003.188
#                 ├── MV.MBRV..SHZ.D.2003.194
#                 ├── MV.MBRV..SHZ.D.2003.193
#                 ├── MV.MBRV..SHZ.D.2003.190
#                 ├── MV.MBRV..SHZ.D.2003.187
#                 ├── MV.MBRV..SHZ.D.2003.195
#                 └── MV.MBRV..SHZ.D.2003.197
# 2003-07-15T00:00:00.000000Z

# %% [markdown]
# ## Example 1: Detect anomalous signals in 1 hour of data
#
# First we load one hour of data from the SDS archive (multiple channels):

# %%
# Get and plot data
seconds = 3600
st = sdsclient.get_waveforms("MV", "*", "*", "?HZ", stime, stime+seconds)
st.plot(equal_scale=False);

# %% [markdown]
# Notice that MV.MBLY..BHZ has large spikes and MV.MBGB..BHZ also looks bad. Earlier in the sequence. Let us delete these so they do not mess up detections.

# %%
st.remove(st.select(id='MV.MBLY..BHZ')[0])
st.remove(st.select(id='MV.MBGB..BHZ')[0])
st.plot(equal_scale=False);

# %% [markdown]
# Run STA/LTA Detector on the final Trace object (MV.MBWH..SHZ) in the Stream. We can use index = -1.

# %%
# Detection
import numpy as np
from obspy.signal.trigger import plot_trigger, classic_sta_lta

st2 = st.copy()

tr_index = -1

Fs = int(np.round(st[tr_index].stats.sampling_rate, 0))
print(f"sampling_rate={Fs}")

# Loading parameters here that worked well in Antelope for a mixture of swarms and pathological data
# This 'real time optimization' project was a sort of Monte Carlo search for best parameters that matched 
# closely hand-picked event times while minimizing false events. However, exact methodology of Antelope
# dbdetect unknown.
sta_secs, lta_secs, threshON, threshOFF, freqmin, freqmax, corners = vsmTools.real_time_optimization(band='all')

st2.filter('bandpass', freqmin=freqmin, freqmax=freqmax, corners=corners)
sta_samples = int(sta_secs * Fs)
lta_samples = int(lta_secs * Fs)

#cft = recursive_sta_lta(st2[tr_index].data, sta_samples, lta_samples )
#threshOFF = 1.2
cft = classic_sta_lta(st2[tr_index].data, sta_samples, lta_samples )

plot_trigger(st2[tr_index], cft, threshON, threshOFF)
# Out:
# sampling_rate=75

# %% [markdown]
# The top plot shows Trigger ON (red lines) and Trigger OFF (blue lines) times. The bottom line shows the STA:LTA ratio, where "Trigger ON" (red) corresponds to 2.4, and "Trigger OFF" corresponds to 0.5).
#
# ## Example 2: Run STA/LTA on all (good) channels
# Next we run `coincidence_trigger` on the whole Stream object, choosing the same 'Classic STA/LTA" method as before, and the same input parameters. Since we have 6 'good' channels (Trace objects), we will require at least 3 stations to trigger ON at the same time before a network trigger is declared.

# %%
from obspy.signal.trigger import coincidence_trigger
from pprint import pprint

threshStations = 3 # minimum number of channels that must reach trigger ON at the same time before a network trigger is declared.
max_secs = 120.0 # no trigger will remain on for longer than 2 minutes

staltamethod = 'classicstalta'
trig = coincidence_trigger(staltamethod, threshON , threshOFF, st2, threshStations, sta=sta_secs, lta=lta_secs, max_trigger_length=max_secs, details=True)

for i, this_trig in enumerate(trig):
    print('\n',f'Event {i}')
    pprint(this_trig)
# Out:
#  Event 0
# {'cft_peak_wmean': 3.1233659373469727,
#  'cft_peaks': [2.617872856205013, 4.021819317810901, 2.7304056380250037],
#  'cft_std_wmean': 0.8070304498486968,
#  'cft_stds': [0.6169588517810961, 1.1829837520495015, 0.6211487457154925],
#  'coincidence_sum': 3.0,
#  'duration': 26.080000042915344,
#  'similarity': {},
#  'stations': ['MBRV', 'MBLG', 'MBGH'],
#  'time': UTCDateTime(2003, 7, 15, 0, 58, 54, 880000),
#  'trace_ids': ['MV.MBRV..SHZ', 'MV.MBLG..SHZ', 'MV.MBGH..BHZ']}

# %% [markdown]
# Three network triggers were declared within that one hour time window.
#
# The trig variable is a list of dictionaries. Each dictionary describes a single network trigger, and contains fields including 'time' which has the UTCDateTime at which the network trigger began, 'coincidence_sum' stores the number of channels that simultaenously triggered (3 for the first two events, 4 for the last), and 'trace_ids' tells us the specific channels that triggered.
#
# We will assume that each trigger a volcano-seismic event, i.e. a transient (short-lived) anomalous signal. ObsPy includes classes (object-oriented blueprints of new data types useful for Seismology) for storing each `Event` within a `Catalog`. The structure of an ObsPy `Event` object is based on the QuakeML format, and though this isn't great match for volcano-seismic events, we will create an `Event` object for each network trigger. However, rather than use an ObsPy `Catalog` object directly, we have created a new class `VolcanoSeismicCatalog` which inherits `Catalog` and expands on it. This should all be invisible to you - it happens in the `tools` package, imported above. All we have to do is call `tools.triggers2catalog` and it returns a `VolcanoSeismicCatalog` object.
#
# It will also segment out a window of data for each Event beginning pretrig seconds before the trigger ON time and ending posttrig seconds after the trigger OFF time.

# %%
import pandas as pd
pretrig = 20 #lta_secs * 2
posttrig = 40 # lta_secs * 2   
#sta_secs, lta_secs, threshON, threshOFF, freqmin, freqmax, corners = tools.real_time_optimization(band='all')
catalogObj = vsmTools.triggers2catalog(trig, staltamethod, threshON, threshOFF, \
                                                  sta_secs, lta_secs, max_secs, stream=st2, pretrig=pretrig, posttrig=posttrig )
    
print(catalogObj)
# Out:
# 3 Event(s) in Catalog:
# 2003-07-15T00:20:33.240000Z | None, None | 2.96 None
# 2003-07-15T00:33:13.720000Z | None, None | 2.74 None
# 2003-07-15T00:58:54.880000Z | None, None | 2.89 None

# %% [markdown]
# By expanding on the ObsPy `Catalog` class, we have added several new methods, some of which we will use. For example, for each `Event` we create a `Stream` object and can plot those with:

# %%
catalogObj.plot_streams()
# Out:
# EVENT NUMBER:  1 time:  2003-07-15T00:20:13.240000Z
# EVENT NUMBER:  2 time:  2003-07-15T00:32:53.720000Z
# EVENT NUMBER:  3 time:  2003-07-15T00:58:34.880000Z

# %% [markdown]
# So we have the basic ability to detect events. Unlike the examples in the presentation which are chosen for clarity and having an excellent signal to noise ratio, the events shown in the plots above are not really obvious at all. This is quite typical. Indeed, in this case we are trying to detect events amongst a background of heightened unrest - earthquake swarms that became drumbeat-like and merge into a continuous tremor. It is important to note that STA/LTA algorithms often break down when volcano-seismicity is at its highest!
#
# Anyway, let us now try to run this on several days on data and see how many events we can detect.

# %% [markdown]
# ## Example 3: Run coincidence trigger on multiple days, and concatenate catalogs for each day into one

# %%
import os
import sys
from pprint import pprint 
import obspy
sys.path.append('.')
import vsmTools
SDS_DIR = os.path.join('..', 'data','continuous','SDS')
EVENTS_DIR = os.path.join('..', 'data','events')

# Create a connection to an SDS archive
from obspy.clients.filesystem.sds import Client
sdsclient = Client(str(SDS_DIR))

from obspy.signal.trigger import coincidence_trigger

# set parameters
threshStations = 3 # minimum number of stations that must trigger for a coincidence trigger to occur
max_secs = 120.0
staltamethod = 'classicstalta'
sta_secs, lta_secs, threshON, threshOFF, freqmin, freqmax, corners = vsmTools.real_time_optimization(band='all')

pretrig = 20 #lta_secs * 2
posttrig = 40 # lta_secs * 2   

catalog_all = None

for jday in range(187, 198, 1): # Loop over days in SDS archive
    
    for hour in range(24):

        # set start time
        stime = obspy.UTCDateTime(f"2003{jday}T") + hour * 3600
        print(stime)
    
        # Get and plot data
        st = sdsclient.get_waveforms("MV", "*", "*", "?HZ", stime, stime+3600)
        if len(st)==0:
            continue
    
        # remove bad channels, including those with insufficient samples
        for tr in st:
            if tr.stats.station == 'MBLY' or tr.stats.station == 'MBGB' or tr.stats.npts < max_secs * tr.stats.sampling_rate:
                st.remove(tr)

        if len(st)==0:
            continue
    
        # bandpass filter
        st.filter('bandpass', freqmin=freqmin, freqmax=freqmax, corners=corners)
    
        # run coincidence trigger for this day
        trig = coincidence_trigger(staltamethod, threshON , threshOFF, st, threshStations, sta=sta_secs, lta=lta_secs, max_trigger_length=max_secs, details=True)
        if len(trig)==0:
            continue

        '''
        for i, this_trig in enumerate(trig):
            print(i, this_trig['time'])
        '''
            
        # create catalog object
        catalogObj = vsmTools.triggers2catalog(trig, staltamethod, threshON, threshOFF, \
                                                      sta_secs, lta_secs, max_secs, stream=st, pretrig=pretrig, posttrig=posttrig )
    
        # save the event streams to miniseed, and then erase them to free up memory
        catalogObj.write_events(outdir=EVENTS_DIR)
        catalogObj.streams = []
    
        # concatenate catalogs
        if catalog_all:
            catalog_all.concat(catalogObj)
        else:
            catalog_all = catalogObj
# Out:
# 2003-07-06T00:00:00.000000Z
# 2003-07-06T01:00:00.000000Z
# 2003-07-06T02:00:00.000000Z
# 2003-07-06T03:00:00.000000Z
# 2003-07-06T04:00:00.000000Z
# 2003-07-06T05:00:00.000000Z
# 2003-07-06T06:00:00.000000Z
# 2003-07-06T07:00:00.000000Z
# 2003-07-06T08:00:00.000000Z
# 2003-07-06T09:00:00.000000Z
# 2003-07-06T10:00:00.000000Z
# 2003-07-06T11:00:00.000000Z
# 2003-07-06T12:00:00.000000Z
# 2003-07-06T13:00:00.000000Z
# 2003-07-06T14:00:00.000000Z
# 2003-07-06T15:00:00.000000Z
# 2003-07-06T16:00:00.000000Z
# 2003-07-06T17:00:00.000000Z
# 2003-07-06T18:00:00.000000Z
# 2003-07-06T19:00:00.000000Z
# 2003-07-06T20:00:00.000000Z
# 2003-07-06T21:00:00.000000Z
# 2003-07-06T22:00:00.000000Z
# 2003-07-06T23:00:00.000000Z
# 0 2003-07-06T23:40:14.200000Z
# Writing ../data/events/WAV/MV/2003/07/20030706T234014.mseed
# 2003-07-07T00:00:00.000000Z
# 0 2003-07-07T00:00:14.200000Z
# 1 2003-07-07T00:02:56.920000Z
# 2 2003-07-07T00:34:46.093333Z
# 3 2003-07-07T00:51:51.813333Z
# Writing ../data/events/WAV/MV/2003/07/20030707T000014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T000256.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T003446.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T005151.mseed
# 2003-07-07T01:00:00.000000Z
# 0 2003-07-07T01:00:14.200000Z
# 1 2003-07-07T01:02:33.226667Z
# Writing ../data/events/WAV/MV/2003/07/20030707T010014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T010233.mseed
# 2003-07-07T02:00:00.000000Z
# /home/thompsong/miniconda3/envs/skience24/lib/python3.11/site-packages/obspy/io/mseed/core.py:770: UserWarning: The encoding specified in trace.stats.mseed.encoding does not match the dtype of the data.
# A suitable encoding will be chosen.
#   warnings.warn(msg, UserWarning)
# 0 2003-07-07T02:02:38.946667Z
# 1 2003-07-07T02:42:21.053333Z
# Writing ../data/events/WAV/MV/2003/07/20030707T020238.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T024221.mseed
# 2003-07-07T03:00:00.000000Z
# 0 2003-07-07T03:00:11.840000Z
# 1 2003-07-07T03:03:17.226666Z
# 2 2003-07-07T03:16:07.640000Z
# 3 2003-07-07T03:41:23.280000Z
# Writing ../data/events/WAV/MV/2003/07/20030707T030011.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T030317.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T031607.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T034123.mseed
# 2003-07-07T04:00:00.000000Z
# 0 2003-07-07T04:53:59.773334Z
# Writing ../data/events/WAV/MV/2003/07/20030707T045359.mseed
# 2003-07-07T05:00:00.000000Z
# 0 2003-07-07T05:00:14.200000Z
# 1 2003-07-07T05:08:06.400000Z
# 2 2003-07-07T05:12:17.586666Z
# 3 2003-07-07T05:13:01.933333Z
# 4 2003-07-07T05:48:40.880000Z
# 5 2003-07-07T05:58:16.626666Z
# Writing ../data/events/WAV/MV/2003/07/20030707T050014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T050806.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T051217.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T051301.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T054840.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T055816.mseed
# 2003-07-07T06:00:00.000000Z
# 0 2003-07-07T06:23:48.960000Z
# Writing ../data/events/WAV/MV/2003/07/20030707T062348.mseed
# 2003-07-07T07:00:00.000000Z
# 0 2003-07-07T07:07:25.680000Z
# 1 2003-07-07T07:28:15.986667Z
# 2 2003-07-07T07:39:19.466667Z
# Writing ../data/events/WAV/MV/2003/07/20030707T070725.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T072815.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T073919.mseed
# 2003-07-07T08:00:00.000000Z
# 0 2003-07-07T08:23:07.880000Z
# Writing ../data/events/WAV/MV/2003/07/20030707T082307.mseed
# 2003-07-07T09:00:00.000000Z
# 0 2003-07-07T09:00:14.200000Z
# 1 2003-07-07T09:28:48.946666Z
# 2 2003-07-07T09:48:38.000000Z
# Writing ../data/events/WAV/MV/2003/07/20030707T090014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T092848.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T094838.mseed
# 2003-07-07T10:00:00.000000Z
# 0 2003-07-07T10:02:13.560000Z
# 1 2003-07-07T10:11:27.853334Z
# 2 2003-07-07T10:13:42.026667Z
# 3 2003-07-07T10:50:07.080000Z
# Writing ../data/events/WAV/MV/2003/07/20030707T100213.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T101127.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T101342.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T105007.mseed
# 2003-07-07T11:00:00.000000Z
# 0 2003-07-07T11:00:14.200000Z
# 1 2003-07-07T11:03:18.080000Z
# 2 2003-07-07T11:12:28.600000Z
# 3 2003-07-07T11:14:31.826666Z
# 4 2003-07-07T11:37:48.493334Z
# Writing ../data/events/WAV/MV/2003/07/20030707T110014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T110318.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T111228.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T111431.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T113748.mseed
# 2003-07-07T12:00:00.000000Z
# 0 2003-07-07T12:00:14.200000Z
# 1 2003-07-07T12:14:24.506667Z
# 2 2003-07-07T12:37:36.693333Z
# Writing ../data/events/WAV/MV/2003/07/20030707T120014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T121424.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T123736.mseed
# 2003-07-07T13:00:00.000000Z
# 0 2003-07-07T13:03:30.986667Z
# 1 2003-07-07T13:20:34.413333Z
# 2 2003-07-07T13:32:28.120000Z
# 3 2003-07-07T13:48:56.613333Z
# Writing ../data/events/WAV/MV/2003/07/20030707T130330.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T132034.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T133228.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T134856.mseed
# 2003-07-07T14:00:00.000000Z
# 0 2003-07-07T14:00:14.200000Z
# 1 2003-07-07T14:37:42.200000Z
# Writing ../data/events/WAV/MV/2003/07/20030707T140014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T143742.mseed
# 2003-07-07T15:00:00.000000Z
# 0 2003-07-07T15:27:18.266666Z
# 1 2003-07-07T15:51:33.866667Z
# Writing ../data/events/WAV/MV/2003/07/20030707T152718.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T155133.mseed
# 2003-07-07T16:00:00.000000Z
# 0 2003-07-07T16:23:13.400000Z
# 1 2003-07-07T16:27:58.053333Z
# 2 2003-07-07T16:48:06.640000Z
# Writing ../data/events/WAV/MV/2003/07/20030707T162313.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T162758.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T164806.mseed
# 2003-07-07T17:00:00.000000Z
# 0 2003-07-07T17:00:14.200000Z
# 1 2003-07-07T17:14:13.253333Z
# 2 2003-07-07T17:24:58.546666Z
# 3 2003-07-07T17:28:14.480000Z
# 4 2003-07-07T17:34:54.906666Z
# Writing ../data/events/WAV/MV/2003/07/20030707T170014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T171413.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T172458.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T172814.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T173454.mseed
# 2003-07-07T18:00:00.000000Z
# 0 2003-07-07T18:00:14.200000Z
# Writing ../data/events/WAV/MV/2003/07/20030707T180014.mseed
# 2003-07-07T19:00:00.000000Z
# 0 2003-07-07T19:00:14.200000Z
# 1 2003-07-07T19:10:19.026667Z
# 2 2003-07-07T19:15:39.440000Z
# 3 2003-07-07T19:23:54.600000Z
# 4 2003-07-07T19:35:57.093334Z
# Writing ../data/events/WAV/MV/2003/07/20030707T190014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T191019.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T191539.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T192354.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T193557.mseed
# 2003-07-07T20:00:00.000000Z
# 0 2003-07-07T20:00:14.200000Z
# 1 2003-07-07T20:04:01.800000Z
# 2 2003-07-07T20:40:06.653334Z
# Writing ../data/events/WAV/MV/2003/07/20030707T200014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T200401.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T204006.mseed
# 2003-07-07T21:00:00.000000Z
# 0 2003-07-07T21:04:31.120000Z
# 1 2003-07-07T21:10:34.386666Z
# 2 2003-07-07T21:14:13.146666Z
# Writing ../data/events/WAV/MV/2003/07/20030707T210431.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T211034.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T211413.mseed
# 2003-07-07T22:00:00.000000Z
# 0 2003-07-07T22:00:14.200000Z
# 1 2003-07-07T22:05:14.173333Z
# 2 2003-07-07T22:33:26.906666Z
# 3 2003-07-07T22:55:39.586666Z
# Writing ../data/events/WAV/MV/2003/07/20030707T220014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T220514.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T223326.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T225539.mseed
# 2003-07-07T23:00:00.000000Z
# 0 2003-07-07T23:00:14.200000Z
# 1 2003-07-07T23:01:20.933333Z
# 2 2003-07-07T23:20:42.133333Z
# 3 2003-07-07T23:23:26.173333Z
# Writing ../data/events/WAV/MV/2003/07/20030707T230014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T230120.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T232042.mseed
# Writing ../data/events/WAV/MV/2003/07/20030707T232326.mseed
# 2003-07-08T00:00:00.000000Z
# 0 2003-07-08T00:13:16.973333Z
# 1 2003-07-08T00:13:49.333333Z
# 2 2003-07-08T00:52:29.173333Z
# Writing ../data/events/WAV/MV/2003/07/20030708T001316.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T001349.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T005229.mseed
# 2003-07-08T01:00:00.000000Z
# 0 2003-07-08T01:00:14.200000Z
# 1 2003-07-08T01:35:35.066666Z
# Writing ../data/events/WAV/MV/2003/07/20030708T010014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T013535.mseed
# 2003-07-08T02:00:00.000000Z
# 0 2003-07-08T02:00:14.200000Z
# 1 2003-07-08T02:29:22.493333Z
# 2 2003-07-08T02:59:02.720000Z
# Writing ../data/events/WAV/MV/2003/07/20030708T020014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T022922.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T025902.mseed
# 2003-07-08T03:00:00.000000Z
# 0 2003-07-08T03:00:14.200000Z
# 1 2003-07-08T03:18:15.040000Z
# 2 2003-07-08T03:28:46.080000Z
# Writing ../data/events/WAV/MV/2003/07/20030708T030014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T031815.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T032846.mseed
# 2003-07-08T04:00:00.000000Z
# 0 2003-07-08T04:00:14.200000Z
# Writing ../data/events/WAV/MV/2003/07/20030708T040014.mseed
# 2003-07-08T05:00:00.000000Z
# 0 2003-07-08T05:00:14.200000Z
# 1 2003-07-08T05:44:43.400000Z
# 2 2003-07-08T05:51:26.893334Z
# Writing ../data/events/WAV/MV/2003/07/20030708T050014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T054443.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T055126.mseed
# 2003-07-08T06:00:00.000000Z
# 0 2003-07-08T06:00:14.200000Z
# 1 2003-07-08T06:20:40.760000Z
# 2 2003-07-08T06:21:03.746666Z
# 3 2003-07-08T06:27:17.186667Z
# 4 2003-07-08T06:58:45.053333Z
# Writing ../data/events/WAV/MV/2003/07/20030708T060014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T062040.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T062103.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T062717.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T065845.mseed
# 2003-07-08T07:00:00.000000Z
# 0 2003-07-08T07:00:14.200000Z
# 1 2003-07-08T07:10:37.920000Z
# 2 2003-07-08T07:56:42.760000Z
# Writing ../data/events/WAV/MV/2003/07/20030708T070014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T071037.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T075642.mseed
# 2003-07-08T08:00:00.000000Z
# 2003-07-08T09:00:00.000000Z
# 0 2003-07-08T09:00:14.200000Z
# 1 2003-07-08T09:22:56.386667Z
# Writing ../data/events/WAV/MV/2003/07/20030708T090014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T092256.mseed
# 2003-07-08T10:00:00.000000Z
# 0 2003-07-08T10:03:17.373334Z
# 1 2003-07-08T10:21:49.453333Z
# 2 2003-07-08T10:36:58.973334Z
# 3 2003-07-08T10:43:45.333334Z
# 4 2003-07-08T10:50:02.906667Z
# Writing ../data/events/WAV/MV/2003/07/20030708T100317.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T102149.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T103658.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T104345.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T105002.mseed
# 2003-07-08T11:00:00.000000Z
# 0 2003-07-08T11:06:53.213333Z
# 1 2003-07-08T11:08:53.760000Z
# Writing ../data/events/WAV/MV/2003/07/20030708T110653.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T110853.mseed
# 2003-07-08T12:00:00.000000Z
# 0 2003-07-08T12:00:14.200000Z
# Writing ../data/events/WAV/MV/2003/07/20030708T120014.mseed
# 2003-07-08T13:00:00.000000Z
# 0 2003-07-08T13:00:14.200000Z
# 1 2003-07-08T13:19:15.293334Z
# Writing ../data/events/WAV/MV/2003/07/20030708T130014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030708T131915.mseed
# 2003-07-08T14:00:00.000000Z
# 2003-07-08T15:00:00.000000Z
# 2003-07-08T16:00:00.000000Z
# 2003-07-08T17:00:00.000000Z
# 2003-07-08T18:00:00.000000Z
# 2003-07-08T19:00:00.000000Z
# 2003-07-08T20:00:00.000000Z
# 2003-07-08T21:00:00.000000Z
# 2003-07-08T22:00:00.000000Z
# 2003-07-08T23:00:00.000000Z
# 2003-07-09T00:00:00.000000Z
# 0 2003-07-09T00:00:14.200000Z
# 1 2003-07-09T00:10:52.453333Z
# 2 2003-07-09T00:17:47.640000Z
# 3 2003-07-09T00:38:17.000000Z
# 4 2003-07-09T00:40:00.480000Z
# Writing ../data/events/WAV/MV/2003/07/20030709T000014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T001052.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T001747.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T003817.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T004000.mseed
# 2003-07-09T01:00:00.000000Z
# 0 2003-07-09T01:00:14.200000Z
# 1 2003-07-09T01:16:28.440000Z
# 2 2003-07-09T01:25:10.013333Z
# 3 2003-07-09T01:28:27.906667Z
# 4 2003-07-09T01:33:45.733334Z
# 5 2003-07-09T01:44:41.933334Z
# 6 2003-07-09T01:52:54.453334Z
# Writing ../data/events/WAV/MV/2003/07/20030709T010014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T011628.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T012510.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T012827.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T013345.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T014441.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T015254.mseed
# 2003-07-09T02:00:00.000000Z
# 0 2003-07-09T02:30:35.026666Z
# 1 2003-07-09T02:37:33.173333Z
# 2 2003-07-09T02:58:20.493333Z
# 3 2003-07-09T02:59:49.146666Z
# Writing ../data/events/WAV/MV/2003/07/20030709T023035.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T023733.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T025820.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T025949.mseed
# 2003-07-09T03:00:00.000000Z
# 0 2003-07-09T03:05:47.920000Z
# 1 2003-07-09T03:23:01.266667Z
# 2 2003-07-09T03:50:20.746667Z
# 3 2003-07-09T03:53:20.520000Z
# Writing ../data/events/WAV/MV/2003/07/20030709T030547.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T032301.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T035020.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T035320.mseed
# 2003-07-09T04:00:00.000000Z
# 0 2003-07-09T04:00:14.200000Z
# 1 2003-07-09T04:04:32.706667Z
# 2 2003-07-09T04:12:51.146667Z
# 3 2003-07-09T04:17:49.893334Z
# 4 2003-07-09T04:22:15.280000Z
# 5 2003-07-09T04:51:01.920000Z
# 6 2003-07-09T04:58:10.586667Z
# Writing ../data/events/WAV/MV/2003/07/20030709T040014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T040432.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T041251.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T041749.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T042215.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T045101.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T045810.mseed
# 2003-07-09T05:00:00.000000Z
# 0 2003-07-09T05:09:59.186667Z
# 1 2003-07-09T05:19:02.306667Z
# 2 2003-07-09T05:23:57.253334Z
# 3 2003-07-09T05:38:28.680000Z
# 4 2003-07-09T05:42:21.293334Z
# 5 2003-07-09T05:48:30.586667Z
# 6 2003-07-09T05:54:34.853334Z
# 7 2003-07-09T05:58:35.653334Z
# Writing ../data/events/WAV/MV/2003/07/20030709T050959.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T051902.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T052357.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T053828.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T054221.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T054830.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T055434.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T055835.mseed
# 2003-07-09T06:00:00.000000Z
# 0 2003-07-09T06:00:14.200000Z
# 1 2003-07-09T06:36:30.453334Z
# Writing ../data/events/WAV/MV/2003/07/20030709T060014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T063630.mseed
# 2003-07-09T07:00:00.000000Z
# 0 2003-07-09T07:11:00.560000Z
# Writing ../data/events/WAV/MV/2003/07/20030709T071100.mseed
# 2003-07-09T08:00:00.000000Z
# 0 2003-07-09T08:00:14.200000Z
# 1 2003-07-09T08:32:02.546667Z
# Writing ../data/events/WAV/MV/2003/07/20030709T080014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T083202.mseed
# 2003-07-09T09:00:00.000000Z
# 0 2003-07-09T09:00:11.480000Z
# 1 2003-07-09T09:12:46.973333Z
# 2 2003-07-09T09:24:47.106666Z
# 3 2003-07-09T09:25:56.306667Z
# 4 2003-07-09T09:27:08.346666Z
# 5 2003-07-09T09:30:04.493334Z
# 6 2003-07-09T09:47:54.720000Z
# Writing ../data/events/WAV/MV/2003/07/20030709T090011.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T091246.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T092447.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T092556.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T092708.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T093004.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T094754.mseed
# 2003-07-09T10:00:00.000000Z
# 0 2003-07-09T10:04:49.760000Z
# 1 2003-07-09T10:13:02.480000Z
# 2 2003-07-09T10:32:23.520000Z
# 3 2003-07-09T10:34:58.160000Z
# Writing ../data/events/WAV/MV/2003/07/20030709T100449.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T101302.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T103223.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T103458.mseed
# 2003-07-09T11:00:00.000000Z
# 0 2003-07-09T11:29:56.186667Z
# 1 2003-07-09T11:47:12.186666Z
# Writing ../data/events/WAV/MV/2003/07/20030709T112956.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T114712.mseed
# 2003-07-09T12:00:00.000000Z
# 0 2003-07-09T12:19:08.786667Z
# 1 2003-07-09T12:38:35.253333Z
# 2 2003-07-09T12:46:53.333333Z
# Writing ../data/events/WAV/MV/2003/07/20030709T121908.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T123835.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T124653.mseed
# 2003-07-09T13:00:00.000000Z
# 0 2003-07-09T13:00:14.200000Z
# 1 2003-07-09T13:08:07.266667Z
# 2 2003-07-09T13:34:55.320000Z
# 3 2003-07-09T13:42:21.120000Z
# Writing ../data/events/WAV/MV/2003/07/20030709T130014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T130807.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T133455.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T134221.mseed
# 2003-07-09T14:00:00.000000Z
# 0 2003-07-09T14:21:51.693334Z
# 1 2003-07-09T14:51:06.346666Z
# Writing ../data/events/WAV/MV/2003/07/20030709T142151.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T145106.mseed
# 2003-07-09T15:00:00.000000Z
# 0 2003-07-09T15:00:14.200000Z
# 1 2003-07-09T15:13:20.466667Z
# 2 2003-07-09T15:52:47.480000Z
# Writing ../data/events/WAV/MV/2003/07/20030709T150014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T151320.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T155247.mseed
# 2003-07-09T16:00:00.000000Z
# 0 2003-07-09T16:00:14.200000Z
# 1 2003-07-09T16:03:53.120000Z
# 2 2003-07-09T16:35:45.746667Z
# 3 2003-07-09T16:36:57.586667Z
# 4 2003-07-09T16:43:01.880000Z
# Writing ../data/events/WAV/MV/2003/07/20030709T160014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T160353.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T163545.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T163657.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T164301.mseed
# 2003-07-09T17:00:00.000000Z
# 0 2003-07-09T17:00:14.200000Z
# 1 2003-07-09T17:03:45.386667Z
# 2 2003-07-09T17:11:04.346666Z
# Writing ../data/events/WAV/MV/2003/07/20030709T170014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T170345.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T171104.mseed
# 2003-07-09T18:00:00.000000Z
# 0 2003-07-09T18:04:21.746666Z
# 1 2003-07-09T18:08:19.893334Z
# 2 2003-07-09T18:31:01.706667Z
# 3 2003-07-09T18:48:00.093334Z
# Writing ../data/events/WAV/MV/2003/07/20030709T180421.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T180819.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T183101.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T184800.mseed
# 2003-07-09T19:00:00.000000Z
# 0 2003-07-09T19:00:11.480000Z
# 1 2003-07-09T19:55:55.160000Z
# Writing ../data/events/WAV/MV/2003/07/20030709T190011.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T195555.mseed
# 2003-07-09T20:00:00.000000Z
# 0 2003-07-09T20:32:43.146667Z
# 1 2003-07-09T20:34:08.066667Z
# Writing ../data/events/WAV/MV/2003/07/20030709T203243.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T203408.mseed
# 2003-07-09T21:00:00.000000Z
# 0 2003-07-09T21:00:14.200000Z
# 1 2003-07-09T21:05:23.546667Z
# 2 2003-07-09T21:48:22.600000Z
# 3 2003-07-09T21:51:45.013333Z
# 4 2003-07-09T21:55:45.146666Z
# Writing ../data/events/WAV/MV/2003/07/20030709T210014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T210523.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T214822.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T215145.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T215545.mseed
# 2003-07-09T22:00:00.000000Z
# 0 2003-07-09T22:00:14.200000Z
# 1 2003-07-09T22:53:58.840000Z
# Writing ../data/events/WAV/MV/2003/07/20030709T220014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T225358.mseed
# 2003-07-09T23:00:00.000000Z
# 0 2003-07-09T23:10:08.986666Z
# 1 2003-07-09T23:12:54.093333Z
# Writing ../data/events/WAV/MV/2003/07/20030709T231008.mseed
# Writing ../data/events/WAV/MV/2003/07/20030709T231254.mseed
# 2003-07-10T00:00:00.000000Z
# 0 2003-07-10T00:24:45.986667Z
# 1 2003-07-10T00:45:18.373333Z
# Writing ../data/events/WAV/MV/2003/07/20030710T002445.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T004518.mseed
# 2003-07-10T01:00:00.000000Z
# 0 2003-07-10T01:43:51.040000Z
# Writing ../data/events/WAV/MV/2003/07/20030710T014351.mseed
# 2003-07-10T02:00:00.000000Z
# 0 2003-07-10T02:00:14.200000Z
# 1 2003-07-10T02:08:58.706667Z
# 2 2003-07-10T02:18:02.266667Z
# 3 2003-07-10T02:21:21.226667Z
# 4 2003-07-10T02:24:14.760000Z
# 5 2003-07-10T02:41:03.426667Z
# 6 2003-07-10T02:46:21.426667Z
# 7 2003-07-10T02:52:05.280000Z
# Writing ../data/events/WAV/MV/2003/07/20030710T020014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T020858.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T021802.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T022121.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T022414.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T024103.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T024621.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T025205.mseed
# 2003-07-10T03:00:00.000000Z
# 0 2003-07-10T03:00:14.200000Z
# 1 2003-07-10T03:06:31.746666Z
# 2 2003-07-10T03:07:25.986667Z
# 3 2003-07-10T03:07:44.093333Z
# 4 2003-07-10T03:09:09.453333Z
# 5 2003-07-10T03:11:01.840000Z
# 6 2003-07-10T03:14:42.306666Z
# 7 2003-07-10T03:19:35.266667Z
# 8 2003-07-10T03:19:54.226666Z
# 9 2003-07-10T03:21:22.293334Z
# 10 2003-07-10T03:23:38.293333Z
# 11 2003-07-10T03:25:56.133333Z
# 12 2003-07-10T03:25:59.120000Z
# 13 2003-07-10T03:34:06.413333Z
# 14 2003-07-10T03:34:08.386666Z
# 15 2003-07-10T03:35:13.306666Z
# 16 2003-07-10T03:42:01.280000Z
# 17 2003-07-10T03:46:11.213333Z
# 18 2003-07-10T03:46:41.120000Z
# 19 2003-07-10T03:49:47.880000Z
# 20 2003-07-10T03:51:49.120000Z
# 21 2003-07-10T03:52:20.066666Z
# 22 2003-07-10T03:54:25.960000Z
# 23 2003-07-10T03:56:04.426666Z
# Writing ../data/events/WAV/MV/2003/07/20030710T030014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T030631.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T030725.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T030744.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T030909.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T031101.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T031442.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T031935.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T031954.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T032122.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T032338.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T032556.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T032559.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T033406.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T033408.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T033513.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T034201.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T034611.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T034641.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T034947.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T035149.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T035220.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T035425.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T035604.mseed
# 2003-07-10T04:00:00.000000Z
# 0 2003-07-10T04:00:14.200000Z
# 1 2003-07-10T04:02:22.320000Z
# 2 2003-07-10T04:02:47.693334Z
# 3 2003-07-10T04:10:19.973334Z
# 4 2003-07-10T04:12:16.066667Z
# 5 2003-07-10T04:12:51.333334Z
# 6 2003-07-10T04:15:14.306667Z
# 7 2003-07-10T04:19:58.386667Z
# 8 2003-07-10T04:20:54.360000Z
# 9 2003-07-10T04:22:25.946667Z
# 10 2003-07-10T04:26:17.626667Z
# 11 2003-07-10T04:27:18.080000Z
# 12 2003-07-10T04:30:02.880000Z
# 13 2003-07-10T04:30:34.146667Z
# 14 2003-07-10T04:31:13.200000Z
# 15 2003-07-10T04:31:49.653334Z
# 16 2003-07-10T04:34:00.053334Z
# 17 2003-07-10T04:34:32.613334Z
# 18 2003-07-10T04:35:02.013334Z
# 19 2003-07-10T04:35:54.613334Z
# 20 2003-07-10T04:38:48.133334Z
# 21 2003-07-10T04:41:06.120000Z
# 22 2003-07-10T04:46:05.013334Z
# 23 2003-07-10T04:48:19.653334Z
# 24 2003-07-10T04:52:24.760000Z
# 25 2003-07-10T04:54:37.026667Z
# Writing ../data/events/WAV/MV/2003/07/20030710T040014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T040222.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T040247.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T041019.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T041216.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T041251.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T041514.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T041958.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T042054.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T042225.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T042617.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T042718.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T043002.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T043034.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T043113.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T043149.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T043400.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T043432.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T043502.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T043554.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T043848.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T044106.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T044605.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T044819.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T045224.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T045437.mseed
# 2003-07-10T05:00:00.000000Z
# 0 2003-07-10T05:00:14.200000Z
# 1 2003-07-10T05:03:50.986666Z
# 2 2003-07-10T05:04:33.760000Z
# 3 2003-07-10T05:07:28.146667Z
# 4 2003-07-10T05:08:36.453333Z
# 5 2003-07-10T05:09:10.000000Z
# 6 2003-07-10T05:10:20.040000Z
# 7 2003-07-10T05:13:18.680000Z
# 8 2003-07-10T05:14:26.773333Z
# 9 2003-07-10T05:17:55.413333Z
# 10 2003-07-10T05:18:27.506666Z
# 11 2003-07-10T05:20:21.626666Z
# 12 2003-07-10T05:22:14.146667Z
# 13 2003-07-10T05:25:37.600000Z
# 14 2003-07-10T05:31:19.066667Z
# 15 2003-07-10T05:36:39.773333Z
# 16 2003-07-10T05:39:29.000000Z
# 17 2003-07-10T05:39:30.493333Z
# 18 2003-07-10T05:44:21.066667Z
# 19 2003-07-10T05:44:56.586667Z
# 20 2003-07-10T05:51:51.613333Z
# 21 2003-07-10T05:52:27.600000Z
# 22 2003-07-10T05:53:38.360000Z
# 23 2003-07-10T05:54:11.786667Z
# 24 2003-07-10T05:55:49.906667Z
# 25 2003-07-10T05:56:25.800000Z
# 26 2003-07-10T05:57:28.973333Z
# 27 2003-07-10T05:59:04.506667Z
# Writing ../data/events/WAV/MV/2003/07/20030710T050014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T050350.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T050433.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T050728.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T050836.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T050910.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T051020.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T051318.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T051426.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T051755.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T051827.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T052021.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T052214.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T052537.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T053119.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T053639.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T053929.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T053930.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T054421.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T054456.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T055151.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T055227.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T055338.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T055411.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T055549.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T055625.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T055728.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T055904.mseed
# 2003-07-10T06:00:00.000000Z
# 0 2003-07-10T06:00:14.200000Z
# 1 2003-07-10T06:02:49.800000Z
# 2 2003-07-10T06:03:22.360000Z
# 3 2003-07-10T06:05:37.040000Z
# 4 2003-07-10T06:07:32.306666Z
# 5 2003-07-10T06:08:45.773333Z
# 6 2003-07-10T06:09:23.053333Z
# 7 2003-07-10T06:10:05.520000Z
# 8 2003-07-10T06:10:30.280000Z
# 9 2003-07-10T06:14:02.840000Z
# 10 2003-07-10T06:14:39.093333Z
# 11 2003-07-10T06:15:12.493333Z
# 12 2003-07-10T06:15:38.573333Z
# 13 2003-07-10T06:18:01.400000Z
# 14 2003-07-10T06:19:40.133333Z
# 15 2003-07-10T06:20:25.466666Z
# 16 2003-07-10T06:20:45.866666Z
# 17 2003-07-10T06:22:50.720000Z
# 18 2003-07-10T06:23:50.493333Z
# 19 2003-07-10T06:25:01.066666Z
# 20 2003-07-10T06:27:04.093333Z
# 21 2003-07-10T06:28:19.786666Z
# 22 2003-07-10T06:28:53.880000Z
# 23 2003-07-10T06:32:06.853333Z
# 24 2003-07-10T06:33:06.013334Z
# 25 2003-07-10T06:36:09.133333Z
# 26 2003-07-10T06:40:45.533333Z
# 27 2003-07-10T06:42:27.173333Z
# 28 2003-07-10T06:43:06.826666Z
# 29 2003-07-10T06:43:40.293333Z
# 30 2003-07-10T06:44:17.226666Z
# 31 2003-07-10T06:46:41.266666Z
# 32 2003-07-10T06:47:16.853333Z
# 33 2003-07-10T06:47:54.906666Z
# 34 2003-07-10T06:57:06.693334Z
# Writing ../data/events/WAV/MV/2003/07/20030710T060014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T060249.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T060322.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T060537.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T060732.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T060845.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T060923.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T061005.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T061030.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T061402.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T061439.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T061512.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T061538.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T061801.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T061940.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T062025.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T062045.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T062250.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T062350.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T062501.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T062704.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T062819.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T062853.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T063206.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T063306.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T063609.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T064045.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T064227.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T064306.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T064340.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T064417.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T064641.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T064716.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T064754.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T065706.mseed
# 2003-07-10T07:00:00.000000Z
# 0 2003-07-10T07:00:11.480000Z
# 1 2003-07-10T07:05:13.280000Z
# 2 2003-07-10T07:05:45.080000Z
# 3 2003-07-10T07:08:23.120000Z
# 4 2003-07-10T07:13:59.666667Z
# 5 2003-07-10T07:16:38.626667Z
# 6 2003-07-10T07:17:52.493333Z
# 7 2003-07-10T07:18:32.533334Z
# 8 2003-07-10T07:19:03.720000Z
# 9 2003-07-10T07:20:22.533333Z
# 10 2003-07-10T07:22:17.466667Z
# 11 2003-07-10T07:23:34.560000Z
# 12 2003-07-10T07:26:05.560000Z
# 13 2003-07-10T07:26:47.666667Z
# 14 2003-07-10T07:30:02.000000Z
# 15 2003-07-10T07:33:20.933333Z
# 16 2003-07-10T07:34:45.906667Z
# 17 2003-07-10T07:36:48.506667Z
# 18 2003-07-10T07:38:10.773333Z
# 19 2003-07-10T07:40:05.866666Z
# 20 2003-07-10T07:40:47.746667Z
# 21 2003-07-10T07:41:32.120000Z
# 22 2003-07-10T07:43:40.080000Z
# 23 2003-07-10T07:44:21.560000Z
# 24 2003-07-10T07:45:03.693333Z
# 25 2003-07-10T07:45:40.413333Z
# 26 2003-07-10T07:47:11.466667Z
# 27 2003-07-10T07:51:30.053333Z
# 28 2003-07-10T07:52:57.200000Z
# 29 2003-07-10T07:53:37.933333Z
# 30 2003-07-10T07:54:18.253333Z
# 31 2003-07-10T07:57:53.360000Z
# Writing ../data/events/WAV/MV/2003/07/20030710T070011.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T070513.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T070545.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T070823.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T071359.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T071638.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T071752.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T071832.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T071903.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T072022.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T072217.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T072334.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T072605.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T072647.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T073002.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T073320.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T073445.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T073648.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T073810.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T074005.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T074047.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T074132.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T074340.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T074421.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T074503.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T074540.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T074711.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T075130.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T075257.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T075337.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T075418.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T075753.mseed
# 2003-07-10T08:00:00.000000Z
# 0 2003-07-10T08:00:12.426667Z
# 1 2003-07-10T08:06:42.213334Z
# 2 2003-07-10T08:07:41.040000Z
# 3 2003-07-10T08:10:00.173333Z
# 4 2003-07-10T08:10:50.293334Z
# 5 2003-07-10T08:11:35.346667Z
# 6 2003-07-10T08:12:23.000000Z
# 7 2003-07-10T08:14:38.666667Z
# 8 2003-07-10T08:17:38.293333Z
# 9 2003-07-10T08:19:03.106667Z
# 10 2003-07-10T08:20:36.933333Z
# 11 2003-07-10T08:23:33.866667Z
# 12 2003-07-10T08:24:16.600000Z
# 13 2003-07-10T08:25:00.946667Z
# 14 2003-07-10T08:25:28.026667Z
# 15 2003-07-10T08:27:00.480000Z
# 16 2003-07-10T08:29:30.840000Z
# 17 2003-07-10T08:31:43.426667Z
# 18 2003-07-10T08:36:14.146667Z
# 19 2003-07-10T08:42:53.453333Z
# 20 2003-07-10T08:45:06.266667Z
# 21 2003-07-10T08:45:48.666667Z
# 22 2003-07-10T08:46:33.960000Z
# 23 2003-07-10T08:47:10.013333Z
# 24 2003-07-10T08:49:27.120000Z
# 25 2003-07-10T08:50:11.466667Z
# 26 2003-07-10T08:52:25.226667Z
# 27 2003-07-10T08:53:11.746667Z
# 28 2003-07-10T08:58:44.040000Z
# Writing ../data/events/WAV/MV/2003/07/20030710T080012.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T080642.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T080741.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T081000.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T081050.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T081135.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T081223.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T081438.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T081738.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T081903.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T082036.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T082333.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T082416.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T082500.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T082528.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T082700.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T082930.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T083143.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T083614.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T084253.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T084506.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T084548.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T084633.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T084710.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T084927.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T085011.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T085225.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T085311.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T085844.mseed
# 2003-07-10T09:00:00.000000Z
# 0 2003-07-10T09:00:14.200000Z
# 1 2003-07-10T09:03:42.026667Z
# 2 2003-07-10T09:05:18.253333Z
# 3 2003-07-10T09:10:32.573333Z
# 4 2003-07-10T09:14:22.173333Z
# 5 2003-07-10T09:16:33.480000Z
# 6 2003-07-10T09:17:51.546667Z
# 7 2003-07-10T09:23:22.640000Z
# 8 2003-07-10T09:26:30.613333Z
# 9 2003-07-10T09:31:15.533333Z
# 10 2003-07-10T09:31:59.973333Z
# 11 2003-07-10T09:38:39.146667Z
# 12 2003-07-10T09:41:02.773333Z
# 13 2003-07-10T09:42:38.493333Z
# 14 2003-07-10T09:43:27.280000Z
# 15 2003-07-10T09:45:44.133333Z
# 16 2003-07-10T09:53:33.786667Z
# 17 2003-07-10T09:59:22.346667Z
# Writing ../data/events/WAV/MV/2003/07/20030710T090014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T090342.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T090518.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T091032.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T091422.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T091633.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T091751.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T092322.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T092630.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T093115.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T093159.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T093839.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T094102.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T094238.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T094327.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T094544.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T095333.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T095922.mseed
# 2003-07-10T10:00:00.000000Z
# 0 2003-07-10T10:00:11.480000Z
# 1 2003-07-10T10:02:41.226666Z
# 2 2003-07-10T10:04:21.893333Z
# 3 2003-07-10T10:05:05.306667Z
# 4 2003-07-10T10:06:48.240000Z
# 5 2003-07-10T10:09:16.613333Z
# 6 2003-07-10T10:11:48.400000Z
# 7 2003-07-10T10:12:35.106666Z
# 8 2003-07-10T10:14:50.613334Z
# 9 2003-07-10T10:15:37.946667Z
# 10 2003-07-10T10:18:08.080000Z
# 11 2003-07-10T10:18:58.066667Z
# 12 2003-07-10T10:19:44.106667Z
# 13 2003-07-10T10:22:11.453334Z
# 14 2003-07-10T10:23:39.306667Z
# 15 2003-07-10T10:24:38.146667Z
# 16 2003-07-10T10:26:20.586666Z
# 17 2003-07-10T10:34:18.760000Z
# 18 2003-07-10T10:35:24.253334Z
# 19 2003-07-10T10:36:06.400000Z
# 20 2003-07-10T10:36:59.973334Z
# 21 2003-07-10T10:38:44.600000Z
# 22 2003-07-10T10:47:39.333334Z
# 23 2003-07-10T10:48:52.480000Z
# 24 2003-07-10T10:49:50.680000Z
# 25 2003-07-10T10:51:29.840000Z
# 26 2003-07-10T10:52:53.613334Z
# 27 2003-07-10T10:54:11.133334Z
# 28 2003-07-10T10:54:58.986667Z
# 29 2003-07-10T10:59:24.546666Z
# Writing ../data/events/WAV/MV/2003/07/20030710T100011.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T100241.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T100421.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T100505.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T100648.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T100916.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T101148.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T101235.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T101450.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T101537.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T101808.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T101858.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T101944.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T102211.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T102339.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T102438.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T102620.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T103418.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T103524.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T103606.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T103659.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T103844.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T104739.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T104852.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T104950.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T105129.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T105253.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T105411.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T105458.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T105924.mseed
# 2003-07-10T11:00:00.000000Z
# 0 2003-07-10T11:00:12.986667Z
# 1 2003-07-10T11:02:48.813333Z
# 2 2003-07-10T11:09:15.653334Z
# 3 2003-07-10T11:10:07.506666Z
# 4 2003-07-10T11:11:08.626667Z
# 5 2003-07-10T11:12:56.920000Z
# 6 2003-07-10T11:16:38.266666Z
# 7 2003-07-10T11:18:27.520000Z
# 8 2003-07-10T11:19:36.186667Z
# 9 2003-07-10T11:23:16.506667Z
# 10 2003-07-10T11:24:08.920000Z
# 11 2003-07-10T11:25:05.973333Z
# 12 2003-07-10T11:28:43.000000Z
# 13 2003-07-10T11:29:55.600000Z
# 14 2003-07-10T11:30:54.093334Z
# 15 2003-07-10T11:31:48.146666Z
# 16 2003-07-10T11:33:45.040000Z
# 17 2003-07-10T11:35:42.160000Z
# 18 2003-07-10T11:40:03.120000Z
# 19 2003-07-10T11:41:59.520000Z
# 20 2003-07-10T11:45:37.746667Z
# 21 2003-07-10T11:47:19.120000Z
# 22 2003-07-10T11:48:22.093334Z
# 23 2003-07-10T11:50:23.040000Z
# 24 2003-07-10T11:54:02.026667Z
# 25 2003-07-10T11:57:46.360000Z
# 26 2003-07-10T11:59:26.853333Z
# Writing ../data/events/WAV/MV/2003/07/20030710T110012.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T110248.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T110915.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T111007.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T111108.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T111256.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T111638.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T111827.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T111936.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T112316.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T112408.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T112505.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T112843.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T112955.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T113054.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T113148.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T113345.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T113542.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T114003.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T114159.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T114537.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T114719.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T114822.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T115023.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T115402.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T115746.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T115926.mseed
# 2003-07-10T12:00:00.000000Z
# 0 2003-07-10T12:00:14.200000Z
# 1 2003-07-10T12:05:16.293333Z
# 2 2003-07-10T12:06:12.613333Z
# 3 2003-07-10T12:08:06.866666Z
# 4 2003-07-10T12:10:03.240000Z
# 5 2003-07-10T12:11:06.813333Z
# 6 2003-07-10T12:14:55.853333Z
# 7 2003-07-10T12:16:45.373333Z
# 8 2003-07-10T12:16:48.160000Z
# 9 2003-07-10T12:18:15.640000Z
# 10 2003-07-10T12:18:39.720000Z
# 11 2003-07-10T12:22:35.920000Z
# 12 2003-07-10T12:24:25.293333Z
# 13 2003-07-10T12:26:23.906666Z
# 14 2003-07-10T12:28:23.960000Z
# 15 2003-07-10T12:29:18.186666Z
# 16 2003-07-10T12:32:11.573333Z
# 17 2003-07-10T12:32:13.586667Z
# 18 2003-07-10T12:34:02.400000Z
# 19 2003-07-10T12:34:50.200000Z
# 20 2003-07-10T12:36:53.293333Z
# 21 2003-07-10T12:39:48.960000Z
# 22 2003-07-10T12:44:12.693334Z
# 23 2003-07-10T12:56:01.733333Z
# 24 2003-07-10T12:58:59.000000Z
# 25 2003-07-10T12:59:54.613333Z
# Writing ../data/events/WAV/MV/2003/07/20030710T120014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T120516.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T120612.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T120806.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T121003.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T121106.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T121455.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T121645.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T121648.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T121815.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T121839.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T122235.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T122425.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T122623.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T122823.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T122918.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T123211.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T123213.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T123402.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T123450.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T123653.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T123948.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T124412.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T125601.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T125859.mseed
# Writing ../data/events/WAV/MV/2003/07/20030710T125954.mseed
# 2003-07-10T13:00:00.000000Z
# 0 2003-07-10T13:00:14.200000Z
# 1 2003-07-10T13:03:55.226667Z
# 2 2003-07-10T13:03:55.480000Z
# 3 2003-07-10T13:05:42.120000Z
# 4 2003-07-10T13:09:57.866666Z
# 5 2003-07-10T13:10:52.546666Z
# 6 2003-07-10T13:14:32.373333Z
# 7 2003-07-10T13:16:32.293333Z
# 8 2003-07-10T13:17:26.053333Z
# 9 2003-07-10T13:21:21.386666Z
# 10 2003-07-10T13:22:11.520000Z
# 11 2003-07-10T13:23:13.306666Z
# 12 2003-07-10T13:24:13.893333Z
# 13 2003-07-10T13:25:17.986667Z
# 14 2003-07-10T13:28:07.520000Z
# 15 2003-07-10T13:32:00.040000Z
# 16 2003-07-10T13:33:44.586667Z
# 17 2003-07-10T13:35:38.053333Z
# 18 2003-07-10T13:37:39.546667Z
# 19 2003-07-10T13:42:15.413333Z
# 20 2003-07-10T13:45:10.680000Z
# ...
# Writing ../data/events/WAV/MV/2003/07/20030714T173618.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T173736.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T173836.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T174120.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T174451.mseed
# 2003-07-14T18:00:00.000000Z
# 0 2003-07-14T18:08:39.066666Z
# 1 2003-07-14T18:11:39.333333Z
# 2 2003-07-14T18:22:28.986666Z
# 3 2003-07-14T18:31:13.746667Z
# 4 2003-07-14T18:33:20.240000Z
# 5 2003-07-14T18:38:19.760000Z
# 6 2003-07-14T18:40:39.853333Z
# 7 2003-07-14T18:42:42.053334Z
# Writing ../data/events/WAV/MV/2003/07/20030714T180839.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T181139.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T182228.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T183113.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T183320.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T183819.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T184039.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T184242.mseed
# 2003-07-14T19:00:00.000000Z
# 0 2003-07-14T19:13:03.840000Z
# 1 2003-07-14T19:20:14.440000Z
# 2 2003-07-14T19:30:50.760000Z
# Writing ../data/events/WAV/MV/2003/07/20030714T191303.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T192014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T193050.mseed
# 2003-07-14T20:00:00.000000Z
# 0 2003-07-14T20:23:25.493333Z
# 1 2003-07-14T20:58:53.986666Z
# Writing ../data/events/WAV/MV/2003/07/20030714T202325.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T205853.mseed
# 2003-07-14T21:00:00.000000Z
# 0 2003-07-14T21:08:56.786667Z
# 1 2003-07-14T21:32:40.040000Z
# 2 2003-07-14T21:37:59.226667Z
# 3 2003-07-14T21:41:35.280000Z
# 4 2003-07-14T21:41:36.626667Z
# 5 2003-07-14T21:45:39.840000Z
# 6 2003-07-14T21:59:32.906666Z
# Writing ../data/events/WAV/MV/2003/07/20030714T210856.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T213240.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T213759.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T214135.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T214136.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T214539.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T215932.mseed
# 2003-07-14T22:00:00.000000Z
# 0 2003-07-14T22:02:22.720000Z
# 1 2003-07-14T22:08:52.133333Z
# 2 2003-07-14T22:13:28.733333Z
# 3 2003-07-14T22:16:55.240000Z
# 4 2003-07-14T22:28:39.680000Z
# 5 2003-07-14T22:52:16.506666Z
# Writing ../data/events/WAV/MV/2003/07/20030714T220222.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T220852.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T221328.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T221655.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T222839.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T225216.mseed
# 2003-07-14T23:00:00.000000Z
# 0 2003-07-14T23:11:13.960000Z
# 1 2003-07-14T23:16:00.720000Z
# 2 2003-07-14T23:49:11.386667Z
# Writing ../data/events/WAV/MV/2003/07/20030714T231113.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T231600.mseed
# Writing ../data/events/WAV/MV/2003/07/20030714T234911.mseed
# 2003-07-15T00:00:00.000000Z
# 0 2003-07-15T00:20:33.240000Z
# 1 2003-07-15T00:33:13.720000Z
# 2 2003-07-15T00:58:54.880000Z
# Writing ../data/events/WAV/MV/2003/07/20030715T002033.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T003313.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T005854.mseed
# 2003-07-15T01:00:00.000000Z
# 0 2003-07-15T01:11:15.146667Z
# 1 2003-07-15T01:14:56.853334Z
# 2 2003-07-15T01:28:32.520000Z
# 3 2003-07-15T01:37:35.386667Z
# Writing ../data/events/WAV/MV/2003/07/20030715T011115.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T011456.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T012832.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T013735.mseed
# 2003-07-15T02:00:00.000000Z
# 0 2003-07-15T02:13:46.600000Z
# 1 2003-07-15T02:43:41.586666Z
# 2 2003-07-15T02:45:29.413333Z
# Writing ../data/events/WAV/MV/2003/07/20030715T021346.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T024341.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T024529.mseed
# 2003-07-15T03:00:00.000000Z
# 0 2003-07-15T03:44:34.346667Z
# 1 2003-07-15T03:53:03.480000Z
# Writing ../data/events/WAV/MV/2003/07/20030715T034434.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T035303.mseed
# 2003-07-15T04:00:00.000000Z
# 0 2003-07-15T04:08:31.146666Z
# 1 2003-07-15T04:13:36.773333Z
# 2 2003-07-15T04:18:20.200000Z
# 3 2003-07-15T04:47:16.706667Z
# Writing ../data/events/WAV/MV/2003/07/20030715T040831.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T041336.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T041820.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T044716.mseed
# 2003-07-15T05:00:00.000000Z
# 0 2003-07-15T05:28:13.466666Z
# 1 2003-07-15T05:29:12.186666Z
# 2 2003-07-15T05:43:16.066666Z
# 3 2003-07-15T05:44:00.493333Z
# 4 2003-07-15T05:44:35.466666Z
# 5 2003-07-15T05:58:30.066667Z
# Writing ../data/events/WAV/MV/2003/07/20030715T052813.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T052912.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T054316.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T054400.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T054435.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T055830.mseed
# 2003-07-15T06:00:00.000000Z
# 0 2003-07-15T06:38:50.360000Z
# 1 2003-07-15T06:39:44.413333Z
# 2 2003-07-15T06:42:04.986667Z
# 3 2003-07-15T06:48:58.520000Z
# 4 2003-07-15T06:49:43.586666Z
# Writing ../data/events/WAV/MV/2003/07/20030715T063850.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T063944.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T064204.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T064858.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T064943.mseed
# 2003-07-15T07:00:00.000000Z
# 0 2003-07-15T07:01:03.680000Z
# 1 2003-07-15T07:07:25.493333Z
# 2 2003-07-15T07:17:25.986666Z
# 3 2003-07-15T07:29:44.280000Z
# 4 2003-07-15T07:34:55.826666Z
# Writing ../data/events/WAV/MV/2003/07/20030715T070103.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T070725.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T071725.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T072944.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T073455.mseed
# 2003-07-15T08:00:00.000000Z
# 0 2003-07-15T08:11:35.386667Z
# 1 2003-07-15T08:13:47.026667Z
# 2 2003-07-15T08:14:32.706667Z
# 3 2003-07-15T08:15:49.386667Z
# 4 2003-07-15T08:17:15.440000Z
# 5 2003-07-15T08:18:03.466667Z
# 6 2003-07-15T08:28:44.693333Z
# 7 2003-07-15T08:44:48.946667Z
# 8 2003-07-15T08:49:14.186667Z
# 9 2003-07-15T08:50:14.026667Z
# 10 2003-07-15T08:50:15.640000Z
# 11 2003-07-15T08:52:11.346667Z
# 12 2003-07-15T08:52:52.226667Z
# 13 2003-07-15T08:53:15.640000Z
# Writing ../data/events/WAV/MV/2003/07/20030715T081135.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T081347.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T081432.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T081549.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T081715.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T081803.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T082844.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T084448.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T084914.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T085014.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T085015.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T085211.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T085252.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T085315.mseed
# 2003-07-15T09:00:00.000000Z
# 0 2003-07-15T09:01:46.520000Z
# 1 2003-07-15T09:11:22.173333Z
# 2 2003-07-15T09:33:50.693333Z
# 3 2003-07-15T09:45:19.133333Z
# 4 2003-07-15T09:48:11.386667Z
# 5 2003-07-15T09:48:36.720000Z
# 6 2003-07-15T09:49:55.240000Z
# 7 2003-07-15T09:58:37.120000Z
# Writing ../data/events/WAV/MV/2003/07/20030715T090146.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T091122.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T093350.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T094519.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T094811.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T094836.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T094955.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T095837.mseed
# 2003-07-15T10:00:00.000000Z
# 0 2003-07-15T10:32:31.146667Z
# 1 2003-07-15T10:35:52.346666Z
# Writing ../data/events/WAV/MV/2003/07/20030715T103231.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T103552.mseed
# 2003-07-15T11:00:00.000000Z
# 0 2003-07-15T11:02:17.706666Z
# 1 2003-07-15T11:24:02.520000Z
# 2 2003-07-15T11:24:50.440000Z
# 3 2003-07-15T11:44:05.293333Z
# Writing ../data/events/WAV/MV/2003/07/20030715T110217.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T112402.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T112450.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T114405.mseed
# 2003-07-15T12:00:00.000000Z
# 0 2003-07-15T12:05:15.120000Z
# 1 2003-07-15T12:28:17.560000Z
# Writing ../data/events/WAV/MV/2003/07/20030715T120515.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T122817.mseed
# 2003-07-15T13:00:00.000000Z
# 0 2003-07-15T13:33:57.906667Z
# Writing ../data/events/WAV/MV/2003/07/20030715T133357.mseed
# 2003-07-15T14:00:00.000000Z
# 0 2003-07-15T14:21:24.253333Z
# 1 2003-07-15T14:48:15.000000Z
# 2 2003-07-15T14:55:16.053333Z
# Writing ../data/events/WAV/MV/2003/07/20030715T142124.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T144815.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T145516.mseed
# 2003-07-15T15:00:00.000000Z
# 0 2003-07-15T15:09:32.840000Z
# 1 2003-07-15T15:16:47.240000Z
# Writing ../data/events/WAV/MV/2003/07/20030715T150932.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T151647.mseed
# 2003-07-15T16:00:00.000000Z
# 0 2003-07-15T16:08:55.813333Z
# 1 2003-07-15T16:19:32.746666Z
# 2 2003-07-15T16:20:51.493333Z
# 3 2003-07-15T16:31:33.786667Z
# Writing ../data/events/WAV/MV/2003/07/20030715T160855.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T161932.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T162051.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T163133.mseed
# 2003-07-15T17:00:00.000000Z
# 0 2003-07-15T17:01:20.706666Z
# 1 2003-07-15T17:01:22.040000Z
# 2 2003-07-15T17:02:00.706666Z
# 3 2003-07-15T17:02:27.986666Z
# 4 2003-07-15T17:04:01.693333Z
# 5 2003-07-15T17:15:22.866666Z
# 6 2003-07-15T17:17:58.720000Z
# 7 2003-07-15T17:17:59.386666Z
# 8 2003-07-15T17:38:48.973333Z
# 9 2003-07-15T17:50:44.573333Z
# 10 2003-07-15T17:52:47.653334Z
# Writing ../data/events/WAV/MV/2003/07/20030715T170120.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T170122.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T170200.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T170227.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T170401.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T171522.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T171758.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T171759.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T173848.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T175044.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T175247.mseed
# 2003-07-15T18:00:00.000000Z
# 0 2003-07-15T18:33:12.466666Z
# 1 2003-07-15T18:52:01.693333Z
# Writing ../data/events/WAV/MV/2003/07/20030715T183312.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T185201.mseed
# 2003-07-15T19:00:00.000000Z
# 0 2003-07-15T19:19:51.653333Z
# 1 2003-07-15T19:24:25.893333Z
# 2 2003-07-15T19:25:50.133334Z
# 3 2003-07-15T19:30:27.386666Z
# 4 2003-07-15T19:32:06.040000Z
# Writing ../data/events/WAV/MV/2003/07/20030715T191951.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T192425.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T192550.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T193027.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T193206.mseed
# 2003-07-15T20:00:00.000000Z
# 0 2003-07-15T20:39:02.453333Z
# 1 2003-07-15T20:40:41.626667Z
# 2 2003-07-15T20:45:02.693333Z
# 3 2003-07-15T20:46:53.373333Z
# Writing ../data/events/WAV/MV/2003/07/20030715T203902.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T204041.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T204502.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T204653.mseed
# 2003-07-15T21:00:00.000000Z
# 0 2003-07-15T21:37:08.866667Z
# 1 2003-07-15T21:40:57.893334Z
# Writing ../data/events/WAV/MV/2003/07/20030715T213708.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T214057.mseed
# 2003-07-15T22:00:00.000000Z
# 0 2003-07-15T22:17:41.586667Z
# 1 2003-07-15T22:49:35.946667Z
# 2 2003-07-15T22:52:41.760000Z
# 3 2003-07-15T22:57:14.586667Z
# Writing ../data/events/WAV/MV/2003/07/20030715T221741.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T224935.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T225241.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T225714.mseed
# 2003-07-15T23:00:00.000000Z
# 0 2003-07-15T23:06:58.586666Z
# 1 2003-07-15T23:19:36.106666Z
# 2 2003-07-15T23:22:25.546666Z
# 3 2003-07-15T23:49:44.840000Z
# Writing ../data/events/WAV/MV/2003/07/20030715T230658.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T231936.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T232225.mseed
# Writing ../data/events/WAV/MV/2003/07/20030715T234944.mseed
# 2003-07-16T00:00:00.000000Z
# 0 2003-07-16T00:10:18.013333Z
# 1 2003-07-16T00:28:43.680000Z
# 2 2003-07-16T00:42:46.666667Z
# 3 2003-07-16T00:45:52.866667Z
# 4 2003-07-16T00:46:22.346667Z
# Writing ../data/events/WAV/MV/2003/07/20030716T001018.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T002843.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T004246.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T004552.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T004622.mseed
# 2003-07-16T01:00:00.000000Z
# 0 2003-07-16T01:42:42.946667Z
# 1 2003-07-16T01:50:13.120000Z
# Writing ../data/events/WAV/MV/2003/07/20030716T014242.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T015013.mseed
# 2003-07-16T02:00:00.000000Z
# 0 2003-07-16T02:10:16.640000Z
# 1 2003-07-16T02:40:31.280000Z
# 2 2003-07-16T02:55:19.506667Z
# Writing ../data/events/WAV/MV/2003/07/20030716T021016.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T024031.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T025519.mseed
# 2003-07-16T03:00:00.000000Z
# 0 2003-07-16T03:16:21.480000Z
# 1 2003-07-16T03:18:55.866667Z
# 2 2003-07-16T03:32:58.120000Z
# 3 2003-07-16T03:39:25.053333Z
# 4 2003-07-16T03:48:58.226667Z
# Writing ../data/events/WAV/MV/2003/07/20030716T031621.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T031855.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T033258.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T033925.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T034858.mseed
# 2003-07-16T04:00:00.000000Z
# 0 2003-07-16T04:04:54.106666Z
# 1 2003-07-16T04:08:52.840000Z
# 2 2003-07-16T04:17:42.786667Z
# 3 2003-07-16T04:24:53.853333Z
# 4 2003-07-16T04:28:09.293334Z
# 5 2003-07-16T04:42:07.413333Z
# 6 2003-07-16T04:44:36.200000Z
# Writing ../data/events/WAV/MV/2003/07/20030716T040454.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T040852.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T041742.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T042453.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T042809.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T044207.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T044436.mseed
# 2003-07-16T05:00:00.000000Z
# 0 2003-07-16T05:09:45.626667Z
# 1 2003-07-16T05:18:17.533334Z
# Writing ../data/events/WAV/MV/2003/07/20030716T050945.mseed
# Writing ../data/events/WAV/MV/2003/07/20030716T051817.mseed
# 2003-07-16T06:00:00.000000Z
# 2003-07-16T07:00:00.000000Z
# 2003-07-16T08:00:00.000000Z
# 2003-07-16T09:00:00.000000Z
# 2003-07-16T10:00:00.000000Z
# 2003-07-16T11:00:00.000000Z
# 2003-07-16T12:00:00.000000Z
# 2003-07-16T13:00:00.000000Z
# 2003-07-16T14:00:00.000000Z
# 2003-07-16T15:00:00.000000Z
# 2003-07-16T16:00:00.000000Z
# 2003-07-16T17:00:00.000000Z
# 2003-07-16T18:00:00.000000Z
# 2003-07-16T19:00:00.000000Z
# 2003-07-16T20:00:00.000000Z
# 2003-07-16T21:00:00.000000Z
# 2003-07-16T22:00:00.000000Z
# 2003-07-16T23:00:00.000000Z

# %%
print(catalog_all)
catalog_all.save(CATALOG_DIR,'catalog_MV_200307')
# Out:
# 3225 Event(s) in Catalog:
# 2003-07-06T23:40:14.200000Z | None, None | 2.92 None
# 2003-07-07T00:00:14.200000Z | None, None | 3.23 None
# ...
# 2003-07-16T05:09:45.626667Z | None, None | 3.51 None
# 2003-07-16T05:18:17.533334Z | None, None | 2.93 None
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %%
import pandas as pd
catalog_all.plot_eventrate(binsize=pd.Timedelta(hours=1))
